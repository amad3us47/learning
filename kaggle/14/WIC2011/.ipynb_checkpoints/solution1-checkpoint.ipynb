# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %%
train
# Out:
#       file  NumberOfConnectedComponents_1[0]  NumberOfHoles_1[0]  \
# 0    031_1                                79                  39
# 1    031_2                               109                  34
# 2    034_1                                90                  33
# 3    034_2                               124                  37
# 4    035_1                                83                  63
# ..     ...                               ...                 ...
# 103  093_2                               108                  51
# 104  095_1                                86                  47
# 105  095_2                               114                  59
# 106  096_1                                69                  24
# 107  096_2                                99                  24
#
#      SpatialMoment00  SpatialMoment10  SpatialMoment20  SpatialMoment30  \
# 0              36342       40878300.0     5.766330e+10     8.922610e+13
# ...

# %%
test
# Out:
#    file  NumberOfConnectedComponents_1[0]  NumberOfHoles_1[0]  \
# 0    AA                               118                  52
# 1    AB                               101                  62
# 2    AC                                93                  49
# 3    AD                                97                  55
# 4    AE                               107                  46
# 5    AF                               106                  66
# 6    AG                               105                  40
# 7    AH                               108                  57
# 8    AI                               105                  26
# 9    AJ                               106                  21
# 10   AK                                97                  23
# 11   AM                               105                  67
# 12   AN                                99                  34
# 13   AO                               102                  42
# ...
