# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
validate=pd.read_csv('chess/cross_validation_dataset.csv')
example=pd.read_csv('chess/example_submission.csv')
test=pd.read_csv('chess/test_data.csv')
train=pd.read_csv('chess/training_data.csv')

# %%
train.head()
# Out:
#    Month #  White Player #  Black Player #  Score
# 0        1              73            1246    0.5
# 1        1              73            5097    0.5
# 2        1              73            5104    0.5
# 3        1              73            7321    1.0
# 4        1              73            7375    0.5

# %%
list(train)
# Out:
# ['Month #', 'White Player #', 'Black Player #', 'Score']

# %%
print(train[10:100])
# Out:
#     Month #  White Player #  Black Player #  Score
# 10        1             189            7357    1.0
# 11        1             213            7591    0.0
# 12        1             370              88    0.5
# 13        1             370            1033    0.5
# 14        1             370            3487    0.0
# ..      ...             ...             ...    ...
# 95        1            1855            2599    1.0
# 96        1            1860            2605    0.0
# 97        1            1860            3041    0.5
# 98        1            1932            2487    0.5
# 99        1            1932            4923    0.0
#
# [90 rows x 4 columns]

# %%
plt.figure(figsize=(12,6))
plt.xlabel(train['Score'])
plt.ylabel(train['White Player #'])
plt.show()
