# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("data.csv",encoding='latin')

# %%
data.head(100)
# Out:
#       Year Country                    Region Song language  \
# 0   2010.0    Moldova  Former Socialist Bloc       English
# 1   2010.0     Russia  Former Socialist Bloc       English
# 2   2010.0    Estonia  Former Socialist Bloc       English
# 3   2010.0   Slovakia  Former Socialist Bloc        Slovak
# 4   2010.0   Finland             Scandinavia       Finnish
# ..     ...        ...                    ...           ...
# 72     NaN        NaN                    NaN           NaN
# 73     NaN        NaN                    NaN           NaN
# 74     NaN        NaN                    NaN           NaN
# 75     NaN        NaN                    NaN           NaN
# 76     NaN        NaN                    NaN           NaN
#
#                           Artist                  Song     \
# 0   SunStroke Project and Olia Tira            "Run Away"
# 1                Peter Nalitch Band  "Lost and Forgotten"
# 2    Malcolm Lincoln and Manpower 4               "Siren"
# ...

# %%
data['Place'].isna().sum()
# Out:
# np.int64(77)

# %%
semi=pd.read_csv("Semi-final data by year.csv",encoding="latin-1")
semi.head()
# Out:
#        Year       Countryÿÿ                 Region    Song language  \
# 0  2009 SF1      Montenegro      Former Yugoslavia          English
# 1  2009 SF1  Czech Republic  Former Socialist Bloc  English, Romani
# 2  2009 SF1         Belgium         Western Europe          English
# 3  2009 SF1         Belarus  Former Socialist Bloc          English
# 4  2009 SF1          Sweden            Scandinavia  English, French
#
#            Artistÿÿ                     Songÿÿ English translationÿÿ  Placeÿÿ  \
# 0  Andrea Demirovi?  "Just Get Out of My Life"                     ?       11
# 1          Gipsy.cz              "Aven Romale"       Come in gypsies       18
# 2   Patrick Ouchne                  "Copycat"                     ?       17
# 3      Petr Elfimov      "Eyes That Never Lie"                     ?       13
# 4     Malena Ernman                  "La voix"             The voice        4
#
#    Pointsÿÿ Host country  ... Unnamed: 71 Unnamed: 72 Unnamed: 73  \
# ...

# %%
final=pd.read_csv("Final data by year.csv",encoding="latin-1")
final.head()
# Out:
#    Year Country                    Region             Song language  \
# 0  2009  Lithuania  Former Socialist Bloc         English, Russian
# 1  2009     Israel            Independent  English, Hebrew, Arabic
# 2  2009     France         Western Europe                   French
# 3  2009     Sweden            Scandinavia          English, French
# 4  2009    Croatia      Former Yugoslavia                 Croatian
#
#                    Artist                          Song     \
# 0                 Sasha Son                        "Love"
# 1         Noa and Mira Awad   "There Must Be Another Way"
# 2             Patricia Kaas    "Et s'il fallait le faire"
# 3             Malena Ernman                     "La voix"
# 4  Igor Cukrov feat. Andrea                 "Lijepa Tena"
#
#         English translation  Artist gender Group/Solo Place  ...  Unnamed: 65  \
# 0                         ?           Male       Solo    23  ...          NaN
# ...

# %%
main=pd.read_excel("Eurovision Song Contest 2010 dataset.xls")
main.head()
# Out:
#    Year Country                    Region             Song language  \
# 0  2009  Lithuania  Former Socialist Bloc         English, Russian
# 1  2009     Israel            Independent  English, Hebrew, Arabic
# 2  2009     France         Western Europe                   French
# 3  2009     Sweden            Scandinavia          English, French
# 4  2009    Croatia      Former Yugoslavia                 Croatian
#
#                    Artist                          Song     \
# 0                 Sasha Son                        "Love"
# 1         Noa and Mira Awad   "There Must Be Another Way"
# 2             Patricia Kaas    "Et s'il fallait le faire"
# 3             Malena Ernman                     "La voix"
# 4  Igor Cukrov feat. Andrea                 "Lijepa Tena"
#
#         English translation  Artist gender Group/Solo Place  ...  Serbia   \
# 0                         —           Male       Solo    23  ...      0.0
# ...
