# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sam=pd.read_csv("sample_submission.csv")

# %%
test=pd.read_csv("social_test.txt")

# %%
test.shape
# Out:
# (8959, 2)

# %%
sam.shape
# Out:
# (8959, 3)

# %%
sam.head()
# Out:
#     776731  264324  0.326395191186
# 0   666155   95308        0.896051
# 1   535123  755942        0.334125
# 2   786734  712538        0.177526
# 3  1064729    3905        0.415415
# 4   486287  372384        0.981808

# %%
test.head()
# Out:
#     776731  264324
# 0   666155   95308
# 1   535123  755942
# 2   786734  712538
# 3  1064729    3905
# 4   486287  372384
